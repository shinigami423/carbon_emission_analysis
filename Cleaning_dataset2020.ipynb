# %%
import pandas as pd

# %%
# Load the dataset
file = ("ghgp_data_2010.csv")
GHG_2010_df = pd.read_csv(file, low_memory=False)

# %%
print(GHG_2010_df.columns)
# Out:
# Index(['Facility Id', 'FRS Id', 'Facility Name', 'City', 'State', 'Zip Code',
#        'Address', 'County', 'Latitude', 'Longitude', 'Primary NAICS Code',
#        'Industry Type (subparts)', 'Industry Type (sectors)',
#        'Total reported direct emissions', 'CO2 emissions (non-biogenic) ',
#        'Methane (CH4) emissions ', 'Nitrous Oxide (N2O) emissions ',
#        'HFC emissions', 'PFC emissions', 'SF6 emissions ', 'NF3 emissions',
#        'Other Fully Fluorinated GHG emissions', 'HFE emissions',
#        'Very Short-lived Compounds emissions', 'Other GHGs (metric tons CO2e)',
#        'Biogenic CO2 emissions (metric tons)', 'Stationary Combustion',
#        'Electricity Generation', 'Adipic Acid Production',
#        'Aluminum Production', 'Ammonia Manufacturing', 'Cement Production',
#        'Ferroalloy Production', 'Glass Production',
#        'HCFC�22 Production from HFC�23 Destruction', 'Hydrogen Production',
#        'Iron and Steel Production', 'Lead Production', 'Lime Production',
#        'Miscellaneous Use of Carbonates', 'Nitric Acid Production',
#        'Petrochemical Production', 'Petroleum Refining',
#        'Phosphoric Acid Production', 'Pulp and Paper Manufacturing',
#        'Silicon Carbide Production', 'Soda Ash Manufacturing',
#        'Titanium Dioxide Production', 'Zinc Production', 'Municipal Landfills',
#        'Is some CO2 collected on-site and used to manufacture other products and therefore not emitted from the affected manufacturing process unit(s)? (as reported under Subpart G or S)',
#        'Is some CO2 reported as emissions from the affected manufacturing process unit(s) under Subpart AA, G or P collected and transferred off-site or injected (as reported under Subpart PP)?',
#        'Does the facility employ continuous emissions monitoring? '],
#       dtype='object')

# %%
# Select the columns to keep for the analysis
GHG_2010_df = GHG_2010_df[['Facility Id', 'Facility Name', 'State', 
                           'Latitude', 'Longitude', 
                           'Primary NAICS Code', 'Industry Type (sectors)', 
                           'Total reported direct emissions', 'CO2 emissions (non-biogenic) ']]

# %%
# Check the column data type
GHG_2010_df.dtypes
# Out:
# Facility Id                          int64
# Facility Name                       object
# State                               object
# Latitude                           float64
# Longitude                          float64
# Primary NAICS Code                   int64
# Industry Type (sectors)             object
# Total reported direct emissions     object
# CO2 emissions (non-biogenic)        object
# dtype: object

# %%
# Remove the null value
GHG_2010_df.isnull()
# Out:
#       Facility Id  Facility Name  State  Latitude  Longitude  \
# 0           False          False  False     False      False
# 1           False          False  False     False      False
# 2           False          False  False     False      False
# 3           False          False  False     False      False
# 4           False          False  False     False      False
# ...           ...            ...    ...       ...        ...
# 6292        False          False  False     False      False
# 6293        False          False  False     False      False
# 6294        False          False  False     False      False
# 6295        False          False  False     False      False
# 6296        False          False  False     False      False
#
#       Primary NAICS Code  Industry Type (sectors)  \
# 0                  False                    False
# 1                  False                    False
# 2                  False                    False
# 3                  False                    False
# 4                  False                    False
# ...                  ...                      ...
# 6292               False                    False
# 6293               False                    False
# 6294               False                    False
# 6295               False                    False
# 6296               False                    False
#
#       Total reported direct emissions  CO2 emissions (non-biogenic)
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                          False
# 4                               False                          False
# ...                               ...                            ...
# 6292                            False                          False
# 6293                            False                          False
# 6294                            False                          False
# 6295                            False                          False
# 6296                            False                          False
#
# [6297 rows x 9 columns]

# %%
GHG_2010_df.dropna()
# Out:
#       Facility Id                                   Facility Name State  \
# 0         1004377                  121 REGIONAL DISPOSAL FACILITY    TX
# 1         1000112                                    23rd and 3rd    NY
# 2         1006394                  29-6 #2 Central Delivery Point    NM
# 3         1002885  30-5 Central Delivery Point Compressor Station    NM
# 4         1002707                     31-6 Central Delivery Point    NM
# ...           ...                                             ...   ...
# 6292      1003318                          ZYBACH CRYOGENIC PLANT    TX
# 6293      1001308                      Zeeland Generating Station    MI
# 6294      1000805                              Zion Energy Center    IL
# 6295      1001464                                            Zuni    CO
# 6296      1011696                              white oak landfill    NC
#
#        Latitude   Longitude  Primary NAICS Code  \
# 0     33.298570  -96.535860              562212
# 1     40.663000  -74.000000              221112
# 2     36.745200 -107.445500              213112
# 3     36.811800 -107.403600              213112
# 4     36.836300 -107.419900              213112
# ...         ...         ...                 ...
# 6292  35.605000 -100.148333              211111
# 6293  42.820000  -85.998800              221112
# 6294  42.477600  -87.895000              221112
# 6295  39.736900 -105.016900              221330
# 6296  35.661943  -82.996087              562212
#
#                 Industry Type (sectors) Total reported direct emissions  \
# 0                                 Waste                            0.00
# 1                          Power Plants                       82,959.74
# 2     Petroleum and Natural Gas Systems                       25,176.66
# 3     Petroleum and Natural Gas Systems                       38,883.20
# 4     Petroleum and Natural Gas Systems                       63,884.36
# ...                                 ...                             ...
# 6292  Petroleum and Natural Gas Systems                       53,508.55
# 6293                       Power Plants                      455,591.16
# 6294                       Power Plants                       84,045.04
# 6295                       Power Plants                       44,410.74
# 6296                              Waste                       37,277.00
#
#      CO2 emissions (non-biogenic)
# 0                             0.00
# 1                        82,875.90
# 2                        25,150.90
# 3                        38,843.20
# 4                        63,818.60
# ...                            ...
# 6292                     53,453.20
# 6293                    455,128.10
# 6294                     83,959.00
# 6295                     44,365.80
# 6296                          0.00
#
# [5563 rows x 9 columns]

# %%
GHG_2010_df = GHG_2010_df.rename(columns = {"Facility Id": "Fac_ID",
                                           "Facility Name": "Fac_Name",
                                           "Primary NAICS Code": "NAICS",
                                           "Industry Type (sectors)": "Sector",
                                           "Total reported direct emissions": "Total_Emissions",
                                           "CO2 emissions (non-biogenic) ": "CO2_Emissions"})
GHG_2010_df.head(8)
# Out:
#     Fac_ID                                        Fac_Name State  Latitude  \
# 0  1004377                  121 REGIONAL DISPOSAL FACILITY    TX  33.29857
# 1  1000112                                    23rd and 3rd    NY  40.66300
# 2  1006394                  29-6 #2 Central Delivery Point    NM  36.74520
# 3  1002885  30-5 Central Delivery Point Compressor Station    NM  36.81180
# 4  1002707                     31-6 Central Delivery Point    NM  36.83630
# 5  1003742                            31st Street Landfill    IL  41.83491
# 6  1002718                     32-7 Central Delivery Point    NM  36.93130
# 7  1002721                  32-8 #2 CDP COMPRESSOR STATION    NM  36.95690
#
#    Longitude   NAICS                             Sector Total_Emissions  \
# 0  -96.53586  562212                              Waste            0.00
# 1  -74.00000  221112                       Power Plants       82,959.74
# 2 -107.44550  213112  Petroleum and Natural Gas Systems       25,176.66
# 3 -107.40360  213112  Petroleum and Natural Gas Systems       38,883.20
# 4 -107.41990  213112  Petroleum and Natural Gas Systems       63,884.36
# 5  -87.91633  562212                              Waste       12,869.00
# 6 -107.56040  213112  Petroleum and Natural Gas Systems       56,478.59
# 7 -107.66310  213112  Petroleum and Natural Gas Systems       55,075.09
#
#   CO2_Emissions
# 0          0.00
# 1     82,875.90
# 2     25,150.90
# 3     38,843.20
# 4     63,818.60
# 5           NaN
# 6     56,420.50
# 7     55,018.10

# %%
GHG_2010_df.to_csv("GHG_2010.csv", index = 'False', header = 'True')
