# %%
import pandas as pd

# %%
# Load the dataset
file = ("Em_Unit_Fuel_Type.xlsx")
Em_fuel_type_df = pd.read_excel(file, sheet_name = "UNIT_DATA")

# %%
print(Em_fuel_type_df.columns)
# Out:
# Index(['Facility Id', 'FRS Id', 'Facility Name', 'City', 'State',
#        'Primary NAICS Code', 'Reporting Year', 'Industry Type (subparts)',
#        'Industry Type (sectors)', 'Unit Name', 'Unit Type',
#        'Unit Reporting Method',
#        'Unit Maximum Rated Heat Input Capacity (mmBTU/hr)',
#        'General Fuel Type', 'Unit CO2 emissions (non-biogenic) ',
#        'Unit Methane (CH4) emissions ', 'Unit Nitrous Oxide (N2O) emissions ',
#        'Unit Biogenic CO2 emissions (metric tons)'],
#       dtype='object')

# %%
# Select the columns to keep for the analysis
Em_fuel_type_df = Em_fuel_type_df[['Facility Id', 'Facility Name', 'State',  
                           'Primary NAICS Code', 'Industry Type (sectors)', 
                           'Unit Maximum Rated Heat Input Capacity (mmBTU/hr)',
                            'General Fuel Type']]

# %%
# Check the column data type
Em_fuel_type_df.dtypes
# Out:
# Facility Id                                            int64
# Facility Name                                         object
# State                                                 object
# Primary NAICS Code                                     int64
# Industry Type (sectors)                               object
# Unit Maximum Rated Heat Input Capacity (mmBTU/hr)    float64
# General Fuel Type                                     object
# dtype: object

# %%
# Remove the null value
Em_fuel_type_df.isnull()
# Out:
#         Facility Id  Facility Name  State  Primary NAICS Code  \
# 0             False          False  False               False
# 1             False          False  False               False
# 2             False          False  False               False
# 3             False          False  False               False
# 4             False          False  False               False
# ...             ...            ...    ...                 ...
# 210382        False          False  False               False
# 210383        False          False  False               False
# 210384        False          False  False               False
# 210385        False          False  False               False
# 210386        False          False  False               False
#
#         Industry Type (sectors)  \
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 210382                    False
# 210383                    False
# 210384                    False
# 210385                    False
# 210386                    False
#
#         Unit Maximum Rated Heat Input Capacity (mmBTU/hr)  General Fuel Type
# 0                                                   False              False
# 1                                                   False              False
# 2                                                   False              False
# 3                                                   False              False
# 4                                                   False              False
# ...                                                   ...                ...
# 210382                                              False              False
# 210383                                              False              False
# 210384                                              False              False
# 210385                                              False              False
# 210386                                              False              False
#
# [210387 rows x 7 columns]

# %%
Em_fuel_type_df.dropna()
# Out:
#         Facility Id                     Facility Name State  \
# 0           1012147  17Z Gas Plant - Chevron USA Inc.    CA
# 1           1012147  17Z Gas Plant - Chevron USA Inc.    CA
# 2           1012147  17Z Gas Plant - Chevron USA Inc.    CA
# 3           1012147  17Z Gas Plant - Chevron USA Inc.    CA
# 4           1012147  17Z Gas Plant - Chevron USA Inc.    CA
# ...             ...                               ...   ...
# 210382      1003318            ZYBACH CRYOGENIC PLANT    TX
# 210383      1003318            ZYBACH CRYOGENIC PLANT    TX
# 210384      1003318            ZYBACH CRYOGENIC PLANT    TX
# 210385      1003318            ZYBACH CRYOGENIC PLANT    TX
# 210386      1003318            ZYBACH CRYOGENIC PLANT    TX
#
#         Primary NAICS Code                            Industry Type (sectors)  \
# 0                   211130  Natural Gas and Natural Gas Liquids Suppliers,...
# 1                   211130  Natural Gas and Natural Gas Liquids Suppliers,...
# 2                   211130  Natural Gas and Natural Gas Liquids Suppliers,...
# 3                   211130  Natural Gas and Natural Gas Liquids Suppliers,...
# 4                   211112  Natural Gas and Natural Gas Liquids Suppliers,...
# ...                    ...                                                ...
# 210382              211111                  Petroleum and Natural Gas Systems
# 210383              211111                  Petroleum and Natural Gas Systems
# 210384              211111                  Petroleum and Natural Gas Systems
# 210385              211111                  Petroleum and Natural Gas Systems
# 210386              211111                  Petroleum and Natural Gas Systems
#
#         Unit Maximum Rated Heat Input Capacity (mmBTU/hr) General Fuel Type
# 0                                                    30.0       Natural Gas
# 1                                                    30.0       Natural Gas
# 2                                                    30.0       Natural Gas
# 3                                                    30.0       Natural Gas
# 4                                                    30.0       Natural Gas
# ...                                                   ...               ...
# 210382                                               32.0       Natural Gas
# 210383                                               32.0       Natural Gas
# 210384                                               32.0       Natural Gas
# 210385                                               32.0       Natural Gas
# 210386                                               32.0       Natural Gas
#
# [168339 rows x 7 columns]

# %%
Em_fuel_type_df = Em_fuel_type_df.rename(columns = {"Facility Id": "Fac_ID",
                                                   "Facility Name": "Fac_Name",
                                                   "Primary NAICS Code": "NAICS",
                                                   "Industry Type (sectors)": "Sector",
                                                   "Unit Maximum Rated Heat Input Capacity (mmBTU/hr)": "Max_capacity",
                                                   "General Fuel Type": "Fuel_type"})
Em_fuel_type_df.head(8)
# Out:
#     Fac_ID                          Fac_Name State   NAICS  \
# 0  1012147  17Z Gas Plant - Chevron USA Inc.    CA  211130
# 1  1012147  17Z Gas Plant - Chevron USA Inc.    CA  211130
# 2  1012147  17Z Gas Plant - Chevron USA Inc.    CA  211130
# 3  1012147  17Z Gas Plant - Chevron USA Inc.    CA  211130
# 4  1012147  17Z Gas Plant - Chevron USA Inc.    CA  211112
# 5  1000112                      23rd and 3rd    NY  221112
# 6  1000112                      23rd and 3rd    NY  221112
# 7  1000112                      23rd and 3rd    NY  221112
#
#                                               Sector  Max_capacity  \
# 0  Natural Gas and Natural Gas Liquids Suppliers,...          30.0
# 1  Natural Gas and Natural Gas Liquids Suppliers,...          30.0
# 2  Natural Gas and Natural Gas Liquids Suppliers,...          30.0
# 3  Natural Gas and Natural Gas Liquids Suppliers,...          30.0
# 4  Natural Gas and Natural Gas Liquids Suppliers,...          30.0
# 5                                       Power Plants           NaN
# 6                                       Power Plants           NaN
# 7                                       Power Plants           7.4
#
#      Fuel_type
# 0  Natural Gas
# 1  Natural Gas
# 2  Natural Gas
# 3  Natural Gas
# 4  Natural Gas
# 5  Natural Gas
# 6  Natural Gas
# 7  Natural Gas

# %%
Em_fuel_type_df.drop_duplicates("Fac_ID")
# Out:
#          Fac_ID                                        Fac_Name State   NAICS  \
# 0       1012147                17Z Gas Plant - Chevron USA Inc.    CA  211130
# 5       1000112                                    23rd and 3rd    NY  221112
# 45      1006394                  29-6 #2 Central Delivery Point    NM  213112
# 50      1002885  30-5 Central Delivery Point Compressor Station    NM  213112
# 55      1002707                     31-6 Central Delivery Point    NM  213112
# ...         ...                                             ...   ...     ...
# 210310  1010592                                           Zider    TX  486210
# 210318  1011602                       ZINNIA COMPRESSOR STATION    WV  211111
# 210320  1000805                              Zion Energy Center    IL  221112
# 210363  1001464                                            Zuni    CO  221330
# 210377  1003318                          ZYBACH CRYOGENIC PLANT    TX  211130
#
#                                                    Sector  Max_capacity  \
# 0       Natural Gas and Natural Gas Liquids Suppliers,...     30.000000
# 5                                            Power Plants           NaN
# 45                      Petroleum and Natural Gas Systems     11.720875
# 50                      Petroleum and Natural Gas Systems     11.720875
# 55                      Petroleum and Natural Gas Systems     11.720875
# ...                                                   ...           ...
# 210310                  Petroleum and Natural Gas Systems      8.500000
# 210318                  Petroleum and Natural Gas Systems     17.800000
# 210320                                       Power Plants           NaN
# 210363                                       Power Plants           NaN
# 210377                  Petroleum and Natural Gas Systems     42.615000
#
#           Fuel_type
# 0       Natural Gas
# 5       Natural Gas
# 45      Natural Gas
# 50      Natural Gas
# 55      Natural Gas
# ...             ...
# 210310  Natural Gas
# 210318  Natural Gas
# 210320  Natural Gas
# 210363  Natural Gas
# 210377  Natural Gas
#
# [7589 rows x 7 columns]

# %%
Em_fuel_type_df.to_csv("Em_fuel_type.csv", index = 'False', header = 'True')
