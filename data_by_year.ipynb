# %% [markdown]
# # Direct Emitters

# %%
#  Import and read the excel file.
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
read_file = pd.read_excel('Resources/ghgp_data_by_year.xlsx', sheet_name='Direct Emitters', header = 3)
de_df = pd.DataFrame(read_file, columns=["Facility Id",
                                         "Primary NAICS Code", 
                                         "Latest Reported Industry Type (sectors)" , 
                                         "2020 Total reported direct emissions",
                                         "2019 Total reported direct emissions",
                                         "2018 Total reported direct emissions",
                                         "2017 Total reported direct emissions",
                                         "2016 Total reported direct emissions",
                                         "2015 Total reported direct emissions",
                                         "2014 Total reported direct emissions",
                                         "2013 Total reported direct emissions",
                                         "2012 Total reported direct emissions",
                                         "2011 Total reported direct emissions"])
de_df.dropna(inplace=True)
de_df.head()
# Out:
#     Facility Id  Primary NAICS Code Latest Reported Industry Type (sectors)  \
# 0       1004377              562212                                   Waste
# 4       1000112              221112                            Power Plants
# 8       1003742              562212                                   Waste
# 12      1003188              326113                                Minerals
# 13      1005043              541715                                   Other
#
#     2020 Total reported direct emissions  \
# 0                             504064.000
# 4                              60819.700
# 8                             100500.948
# 12                             29359.640
# 13                             82308.238
#
#     2019 Total reported direct emissions  \
# 0                             518680.250
# 4                              44658.384
# 8                              18925.400
# 12                             30571.636
# 13                            106258.176
#
# ...

# %%
print(de_df.shape)
# Out:
# (5292, 13)

# %%
de_df.dtypes
# Out:
# Facility Id                                  int64
# Primary NAICS Code                           int64
# Latest Reported Industry Type (sectors)     object
# 2020 Total reported direct emissions       float64
# 2019 Total reported direct emissions       float64
# 2018 Total reported direct emissions       float64
# 2017 Total reported direct emissions       float64
# 2016 Total reported direct emissions       float64
# 2015 Total reported direct emissions       float64
# 2014 Total reported direct emissions       float64
# 2013 Total reported direct emissions       float64
# 2012 Total reported direct emissions       float64
# 2011 Total reported direct emissions       float64
# dtype: object

# %%
# de_df.tocsv('data/clean_de.csv')

# %% [markdown]
# # Onshore Oil & Gas Prod.

# %%
read_file = pd.read_excel('Resources/ghgp_data_by_year.xlsx', sheet_name='Onshore Oil & Gas Prod.', header = 3)
oogp_df = pd.DataFrame(read_file, columns=["Facility Id",
                                         "2020 Total reported emissions from Onshore Oil & Gas Production ", 
                                         "2019 Total reported emissions from Onshore Oil & Gas Production " , 
                                         "2018 Total reported emissions from Onshore Oil & Gas Production ",
                                         "2017 Total reported emissions from Onshore Oil & Gas Production ",
                                         "2016 Total reported emissions from Onshore Oil & Gas Production ",
                                         "2015 Total reported emissions from Onshore Oil & Gas Production ",
                                         "2014 Total reported emissions from Onshore Oil & Gas Production ",
                                         "2013 Total reported emissions from Onshore Oil & Gas Production ",
                                         "2012 Total reported emissions from Onshore Oil & Gas Production ",
                                         "2011 Total reported emissions from Onshore Oil & Gas Production "])
oogp_df.dropna(inplace=True)
oogp_df.head()
# Out:
#     Facility Id  \
# 0       1000355
# 2       1009238
# 6       1009170
# 14      1009265
# 16      1008287
#
#     2020 Total reported emissions from Onshore Oil & Gas Production   \
# 0                                          293919.042
# 2                                          586008.596
# 6                                           23735.104
# 14                                         124278.886
# 16                                         319410.352
#
#     2019 Total reported emissions from Onshore Oil & Gas Production   \
# 0                                          330937.720
# 2                                          678933.080
# 6                                           76941.042
# 14                                         215964.304
# 16                                         356909.018
#
#     2018 Total reported emissions from Onshore Oil & Gas Production   \
# 0                                          273069.722
# ...

# %%
print(oogp_df.shape)
# Out:
# (210, 11)

# %%
oogp_df.dtypes
# Out:
# Facility Id                                                           int64
# 2020 Total reported emissions from Onshore Oil & Gas Production     float64
# 2019 Total reported emissions from Onshore Oil & Gas Production     float64
# 2018 Total reported emissions from Onshore Oil & Gas Production     float64
# 2017 Total reported emissions from Onshore Oil & Gas Production     float64
# 2016 Total reported emissions from Onshore Oil & Gas Production     float64
# 2015 Total reported emissions from Onshore Oil & Gas Production     float64
# 2014 Total reported emissions from Onshore Oil & Gas Production     float64
# 2013 Total reported emissions from Onshore Oil & Gas Production     float64
# 2012 Total reported emissions from Onshore Oil & Gas Production     float64
# 2011 Total reported emissions from Onshore Oil & Gas Production     float64
# dtype: object

# %%
# oogp_df.tocsv('data/clean_oogp.csv')

# %% [markdown]
# # Gathering & Boosting

# %%
read_file = pd.read_excel('Resources/ghgp_data_by_year.xlsx', sheet_name='Gathering & Boosting', header = 3)
gnb_df = pd.DataFrame(read_file, columns=["Facility Id",
                                         "2020 Total reported emissions from Gathering & Boosting ", 
                                         "2019 Total reported emissions from Gathering & Boosting " , 
                                         "2018 Total reported emissions from Gathering & Boosting ",
                                         "2017 Total reported emissions from Gathering & Boosting ",
                                         "2016 Total reported emissions from Gathering & Boosting "])
gnb_df.dropna(inplace=True)
gnb_df.head()
# Out:
#    Facility Id  2020 Total reported emissions from Gathering & Boosting   \
# 0      1012156                                           7459.590
# 4      1012353                                         121503.954
# 6      1012154                                         295654.184
# 7      1012251                                         140333.810
# 8      1012248                                         118770.000
#
#    2019 Total reported emissions from Gathering & Boosting   \
# 0                                           9775.942
# 4                                          63401.000
# 6                                         295182.282
# 7                                         238400.620
# 8                                         124295.190
#
#    2018 Total reported emissions from Gathering & Boosting   \
# 0                                          42127.186
# 4                                          36639.172
# 6                                         289504.116
# ...

# %%
print(gnb_df.shape)
# Out:
# (263, 6)

# %%
gnb_df.dtypes
# Out:
# Facility Id                                                   int64
# 2020 Total reported emissions from Gathering & Boosting     float64
# 2019 Total reported emissions from Gathering & Boosting     float64
# 2018 Total reported emissions from Gathering & Boosting     float64
# 2017 Total reported emissions from Gathering & Boosting     float64
# 2016 Total reported emissions from Gathering & Boosting     float64
# dtype: object

# %%
# gnb_df.tocsv('data/clean_gnb.csv')

# %% [markdown]
# # Transmission Pipelines

# %%
read_file = pd.read_excel('Resources/ghgp_data_by_year.xlsx', sheet_name='Transmission Pipelines', header = 3)
tp_df = pd.DataFrame(read_file, columns=["Facility Id",
                                         "2020 Total reported direct emissions from Transmission Pipelines", 
                                         "2019 Total reported direct emissions from Transmission Pipelines" , 
                                         "2018 Total reported direct emissions from Transmission Pipelines",
                                         "2017 Total reported direct emissions from Transmission Pipelines",
                                         "2016 Total reported direct emissions from Transmission Pipelines"])
tp_df.dropna(inplace=True)
tp_df.head()
# Out:
#     Facility Id  \
# 0       1012420
# 1       1012420
# 3       1012420
# 6       1013856
# 20      1012139
#
#     2020 Total reported direct emissions from Transmission Pipelines  \
# 0                                         1036.700000
# 1                                          337.400000
# 3                                           39.500000
# 6                                        84077.619496
# 20                                          18.411694
#
#     2019 Total reported direct emissions from Transmission Pipelines  \
# 0                                         7735.400000
# 1                                         3347.650000
# 3                                         4692.150000
# 6                                       112132.022704
# 20                                        5813.273205
#
#     2018 Total reported direct emissions from Transmission Pipelines  \
# 0                                          717.300000
# ...

# %%
print(tp_df.shape)
# Out:
# (91, 6)

# %%
tp_df.dtypes
# Out:
# Facility Id                                                           int64
# 2020 Total reported direct emissions from Transmission Pipelines    float64
# 2019 Total reported direct emissions from Transmission Pipelines    float64
# 2018 Total reported direct emissions from Transmission Pipelines    float64
# 2017 Total reported direct emissions from Transmission Pipelines    float64
# 2016 Total reported direct emissions from Transmission Pipelines    float64
# dtype: object

# %%
# tp_df.tocsv('data/clean_tp.csv')

# %% [markdown]
# # LDC - Direct Emissions

# %%
read_file = pd.read_excel('Resources/ghgp_data_by_year.xlsx', sheet_name='LDC - Direct Emissions', header = 3)
ldc_df = pd.DataFrame(read_file, columns=["Facility Id",
                                         "2020 Total reported direct emissions from Local Distribution Companies", 
                                         "2019 Total reported direct emissions from Local Distribution Companies" , 
                                         "2018 Total reported direct emissions from Local Distribution Companies",
                                         "2017 Total reported direct emissions from Local Distribution Companies",
                                         "2016 Total reported direct emissions from Local Distribution Companies",
                                         "2015 Total reported direct emissions from Local Distribution Companies",
                                         "2014 Total reported direct emissions from Local Distribution Companies",
                                         "2013 Total reported direct emissions from Local Distribution Companies",
                                         "2012 Total reported direct emissions from Local Distribution Companies",
                                         "2011 Total reported direct emissions from Local Distribution Companies"])
ldc_df.dropna(inplace=True)
ldc_df.head()
# Out:
#    Facility Id  \
# 0      1008026
# 1      1004034
# 4      1007872
# 5      1004794
# 6      1001388
#
#    2020 Total reported direct emissions from Local Distribution Companies  \
# 0                                          74939.996
# 1                                          14759.550
# 4                                         165161.150
# 5                                          17502.600
# 6                                          24108.000
#
#    2019 Total reported direct emissions from Local Distribution Companies  \
# 0                                          74762.846
# 1                                          14674.950
# 4                                         154525.296
# 5                                          17942.600
# 6                                          23137.650
#
#    2018 Total reported direct emissions from Local Distribution Companies  \
# 0                                          99558.146
# ...

# %%
print(ldc_df.shape)
# Out:
# (144, 11)

# %%
ldc_df.dtypes
# Out:
# Facility Id                                                           int64
# 2020 Total reported direct emissions from Transmission Pipelines    float64
# 2019 Total reported direct emissions from Transmission Pipelines    float64
# 2018 Total reported direct emissions from Transmission Pipelines    float64
# 2017 Total reported direct emissions from Transmission Pipelines    float64
# 2016 Total reported direct emissions from Transmission Pipelines    float64
# dtype: object

# %%
# ldc_df.tocsv('data/clean_ldc.csv')

# %% [markdown]
# # SF6 from Elec. Equip.

# %%
read_file = pd.read_excel('Resources/ghgp_data_by_year.xlsx', sheet_name='SF6 from Elec. Equip.', header = 3)
sf6_df = pd.DataFrame(read_file, columns=["Facility Id",
                                         "2020 Total reported direct emissions from Electrical Equipment Use", 
                                         "2019 Total reported direct emissions from Electrical Equipment Use" , 
                                         "2018 Total reported direct emissions from Electrical Equipment Use",
                                         "2017 Total reported direct emissions from Electrical Equipment Use",
                                         "2016 Total reported direct emissions from Electrical Equipment Use",
                                         "2015 Total reported direct emissions from Electrical Equipment Use",
                                         "2014 Total reported direct emissions from Electrical Equipment Use",
                                         "2013 Total reported direct emissions from Electrical Equipment Use",
                                         "2012 Total reported direct emissions from Electrical Equipment Use",
                                         "2011 Total reported direct emissions from Electrical Equipment Use"])
sf6_df.dropna(inplace=True)
sf6_df.head()
# Out:
#    Facility Id  \
# 0      1003708
# 2      1010811
# 3      1010812
# 5      1010076
# 7      1009780
#
#    2020 Total reported direct emissions from Electrical Equipment Use  \
# 0                                          132693.72
# 2                                            7644.84
# 3                                            5264.52
# 5                                            1810.32
# 7                                           40777.80
#
#    2019 Total reported direct emissions from Electrical Equipment Use  \
# 0                                          172689.48
# 2                                            8846.40
# 3                                           10745.64
# 5                                            2845.44
# 7                                            9238.56
#
#    2018 Total reported direct emissions from Electrical Equipment Use  \
# 0                                          169844.04
# 2                                           30171.24
# ...

# %%
print(sf6_df.shape)
# Out:
# (63, 11)

# %%
sf6_df.dtypes
# Out:
# Facility Id                                                             int64
# 2020 Total reported direct emissions from Electrical Equipment Use    float64
# 2019 Total reported direct emissions from Electrical Equipment Use    float64
# 2018 Total reported direct emissions from Electrical Equipment Use    float64
# 2017 Total reported direct emissions from Electrical Equipment Use    float64
# 2016 Total reported direct emissions from Electrical Equipment Use    float64
# 2015 Total reported direct emissions from Electrical Equipment Use    float64
# 2014 Total reported direct emissions from Electrical Equipment Use    float64
# 2013 Total reported direct emissions from Electrical Equipment Use    float64
# 2012 Total reported direct emissions from Electrical Equipment Use    float64
# 2011 Total reported direct emissions from Electrical Equipment Use    float64
# dtype: object

# %%
# sf6_df.tocsv('data/clean_sf6.csv')
